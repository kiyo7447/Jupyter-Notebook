# %%
# 適当なデータを作りMatplotlibを使って円グラフを描画する
# imoprt
import matplotlib.pyplot as plt
# データを作る
data = [1, 2, 3, 4]
# ラベルを作る
labels = ['A', 'B', 'C', 'D']
# 円グラフを描画する
plt.pie(data, labels=labels)
# 描画する
plt.show()
